# %%
# !python -m pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.8.0 does not provide the extra 'srv'

# %%
import pymongo

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://mohamadnematizadehhh:RmFcd2olimAP287f@cluster0.xpdym.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

mydb = client["Friends"]

list_friends = [
    {"name": "ali", "grnder": "Male", "Role": 0},
    {"name": "Maraym", "grnder": "Female", "Role": 1},
    {"name": "Reza", "grnder": "Male", "Role": 2},
    {"name": "Sajjad", "grnder": "Male", "Role": 1},
    {"name": "Mona", "grnder": "Female", "Role": 1},
    {"name": "Amirm", "grnder": "Male", "Role": 0},
    {"name": "Lerfani", "grnder": "Female", "Role": 1},
    {"name": "Armin", "grnder": "Male", "Role": 1},
    {"name": "Mahdiar", "grnder": "Male", "Role": 2},
    {"name": "Sadra", "grnder": "Male", "Role": 0},
    {"name": "Kiya", "grnder": "Male", "Role": 2},
    {"name": "Taha", "grnder": "Male", "Role": 2},
    {"name": "Hamed", "grnder": "Male", "Role": 0},
    {"name": "Amirali", "grnder": "Male", "Role": 2},
    {"name": "Mehdi", "grnder": "Male", "Role": 2},
]

mydb.friends.insert_many(list_friends)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[5], line 24
#       4 mydb = client["Friends"]
#       6 list_friends = [
#       7     {"name": "ali", "grnder": "Male", "Role": 0},
#       8     {"name": "Maraym", "grnder": "Female", "Role": 1},
#    (...)
#      21     {"name": "Mehdi", "grnder": "Male", "Role": 2},
#      22 ]
# ---> 24 mydb.friends.insert_many(list_friends)
#
# File c:\Users\nematizadeh\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# ...

# %%
for doc in  mycol.find({} , {"_id": 0 , "name": 1 , "Role": 1 }) :
    print(doc)
